# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint

# %%
url = 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=sigacrossyear&subject=mathematics&grade=4&subscale=MRPCM&variable=GENDER&jurisdiction=NT,AL,AZ,AK,AR,CA,CO,CT,DE,DC,FL,GA,HI,ID,IL,IN,IA,KS,KY,LA,ME,MD,MA,MI,MN,MS,MO,MT,NE,NV,NH,NJ,NM,NY,NC,ND,OH,OK,OR,PA,RI,SC,SD,TN,TX,UT,VT,VA,WA,WV,WI,WY&stattype=MN:MN&Year=2017,2009'

response = requests.get(url)
data = response.json()
pprint(data)
df = pd.DataFrame.from_dict(data)
#df
# Out:
# {'result': [{'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 238.445992462712,
#              'focalYear': 2009,
#              'gap': 7.99423216858401,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AK',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 230.451760294128,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 235.929342503276,
#              'focalYear': 2009,
#              'gap': 5.468155375457,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AK',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 230.461187127819,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 227.718192632839,
#              'focalYear': 2009,
#              'gap': -4.74037746060901,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AL',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 232.458570093448,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 228.224748889903,
#              'focalYear': 2009,
#              'gap': -3.653732845435,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AL',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 231.878481735338,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 238.824582553911,
#              'focalYear': 2009,
#              'gap': 3.843880385788,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AR',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 234.980702168123,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.199532722541,
#              'focalYear': 2009,
#              'gap': 3.53454513340199,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AR',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 232.664987589139,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 230.283949525528,
#              'focalYear': 2009,
#              'gap': -5.34770617187101,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AZ',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 235.631655697399,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 229.686859196827,
#              'focalYear': 2009,
#              'gap': -3.52818652404503,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'AZ',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 233.215045720872,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 232.613832128934,
#              'focalYear': 2009,
#              'gap': -0.651854042852989,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'CA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 233.265686171787,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 230.676541471285,
#              'focalYear': 2009,
#              'gap': -0.538964046231001,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'CA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 231.215505517516,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.965014985203,
#              'focalYear': 2009,
#              'gap': 3.682821272924,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'CO',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.282193712279,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 242.269801469547,
#              'focalYear': 2009,
#              'gap': 1.13250412435499,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'CO',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.137297345192,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 246.400188234775,
#              'focalYear': 2009,
#              'gap': 4.91257763375998,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'CT',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.487610601015,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 242.961087884902,
#              'focalYear': 2009,
#              'gap': 6.04443755326002,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'CT',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 236.916650331642,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 217.948002311893,
#              'focalYear': 2009,
#              'gap': -13.411007545217,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'DC',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 231.35900985711,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 220.567779686836,
#              'focalYear': 2009,
#              'gap': -10.714000167697,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'DC',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 231.281779854533,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.168719105323,
#              'focalYear': 2009,
#              'gap': 5.57706034258399,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'DE',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 235.591658762739,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 237.751097415943,
#              'focalYear': 2009,
#              'gap': 1.08232140681,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'DE',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 236.668776009133,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 242.544421131539,
#              'focalYear': 2009,
#              'gap': -4.93209333488701,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'FL',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 247.476514466426,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.337322700534,
#              'focalYear': 2009,
#              'gap': -3.89424733695799,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'FL',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 245.231570037492,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.508519873044,
#              'focalYear': 2009,
#              'gap': -0.158230993878988,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'GA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 236.666750866923,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 235.546073931685,
#              'focalYear': 2009,
#              'gap': -0.545291934817016,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'GA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 236.091365866502,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 235.266919542352,
#              'focalYear': 2009,
#              'gap': -2.80853166621299,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'HI',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 238.075451208565,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.13087164232,
#              'focalYear': 2009,
#              'gap': -1.61986733995502,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'HI',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 237.750738982275,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.319928550458,
#              'focalYear': 2009,
#              'gap': -1.765453054663,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'IA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 245.085381605121,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.844168194964,
#              'focalYear': 2009,
#              'gap': 0.850162305969008,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'IA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.994005888995,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.940359127151,
#              'focalYear': 2009,
#              'gap': 0.296977089727989,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'ID',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.643382037423,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.130895814336,
#              'focalYear': 2009,
#              'gap': 1.90199568695098,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'ID',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 238.228900127385,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 239.652688660406,
#              'focalYear': 2009,
#              'gap': 0.00772193013600031,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'IL',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 239.64496673027,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.905252518334,
#              'focalYear': 2009,
#              'gap': 0.302439131888008,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'IL',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 236.602813386446,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 242.987043438065,
#              'focalYear': 2009,
#              'gap': -5.256180212121,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'IN',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 248.243223650186,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 242.229985495663,
#              'focalYear': 2009,
#              'gap': -2.464548449538,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'IN',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 244.694533945201,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 246.161673951684,
#              'focalYear': 2009,
#              'gap': 3.67843587086099,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'KS',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.483238080823,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 244.387211364674,
#              'focalYear': 2009,
#              'gap': 4.53988469322798,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'KS',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 239.847326671446,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.034235631792,
#              'focalYear': 2009,
#              'gap': -0.750398961336003,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'KY',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.784634593128,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 237.567519458031,
#              'focalYear': 2009,
#              'gap': 0.0472422096079868,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'KY',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 237.520277248423,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 230.120956179995,
#              'focalYear': 2009,
#              'gap': 1.51677431327201,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'LA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 228.604181866723,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 228.689939124544,
#              'focalYear': 2009,
#              'gap': -0.661469258616989,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'LA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 229.351408383161,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 253.440566771669,
#              'focalYear': 2009,
#              'gap': 1.887164981637,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 251.553401790032,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 251.08238981527,
#              'focalYear': 2009,
#              'gap': 4.48582128816801,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MA',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 246.596568527102,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 244.240509656657,
#              'focalYear': 2009,
#              'gap': 2.164913165786,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MD',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.075596490871,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.346192959954,
#              'focalYear': 2009,
#              'gap': 4.28284655869601,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MD',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 239.063346401258,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 246.540460792972,
#              'focalYear': 2009,
#              'gap': 6.305619527266,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'ME',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.234841265706,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 242.271086578626,
#              'focalYear': 2009,
#              'gap': 2.715091378642,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'ME',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 239.555995199984,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 237.580286106235,
#              'focalYear': 2009,
#              'gap': 0.768955362593005,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MI',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 236.811330743642,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 234.952981577427,
#              'focalYear': 2009,
#              'gap': 0.671773057000024,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MI',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 234.281208520427,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 251.286895509776,
#              'focalYear': 2009,
#              'gap': 0.887646083660997,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MN',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 250.399249426115,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 247.556901951565,
#              'focalYear': 2009,
#              'gap': 0.375845026189012,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MN',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 247.181056925376,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.233822757796,
#              'focalYear': 2009,
#              'gap': -0.00234134875501013,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MO',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.236164106551,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.093870184191,
#              'focalYear': 2009,
#              'gap': 2.41229037985698,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MO',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 237.681579804334,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 226.683890416927,
#              'focalYear': 2009,
#              'gap': -8.772985060113,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MS',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 235.45687547704,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 227.854993019048,
#              'focalYear': 2009,
#              'gap': -6.04717822124698,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MS',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 233.902171240295,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 247.009873368264,
#              'focalYear': 2009,
#              'gap': 5.66463363389502,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MT',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.345239734369,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.66446493679,
#              'focalYear': 2009,
#              'gap': 1.62305948062101,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'MT',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.041405456169,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.969596598632,
#              'focalYear': 2009,
#              'gap': 2.117429370108,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'NC',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.852167228524,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.579270095996,
#              'focalYear': 2009,
#              'gap': 3.57343761865999,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'NC',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.005832477336,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 246.808845898075,
#              'focalYear': 2009,
#              'gap': 1.18249771400698,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'ND',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 245.626348184068,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.515307074721,
#              'focalYear': 2009,
#              'gap': 0.766450937604986,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'ND',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.748856137116,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 238.756841575707,
#              'focalYear': 2009,
#              'gap': -8.46413168386999,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'NE',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 247.220973259577,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 238.739814286656,
#              'focalYear': 2009,
#              'gap': -5.103605408292,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'NE',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 243.843419694948,
#              'targetYear': 2017,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 252.197425791092,
#              'focalYear': 2009,
#              'gap': 5.18221613556099,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'NH',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 247.015209655531,
#              'targetYear': 2017,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 249.865068529406,
#              'focalYear': 2009,
#              'gap': 6.27330707480399,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'NH',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
# ...
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 235.182812781713,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.76562048852,
#              'focalYear': 2017,
#              'gap': 0.349697707764989,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'SD',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 243.415922780755,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 239.369519248999,
#              'focalYear': 2017,
#              'gap': -1.27211641146599,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'SD',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.641635660465,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.964170847302,
#              'focalYear': 2017,
#              'gap': 4.80085274221199,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'TN',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 232.16331810509,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.416996311284,
#              'focalYear': 2017,
#              'gap': 4.94895592147202,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'TN',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 231.468040389812,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.045566668876,
#              'focalYear': 2017,
#              'gap': 0.160716381669999,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'TX',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.884850287206,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.832105518831,
#              'focalYear': 2017,
#              'gap': 0.805878876894013,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'TX',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.026226641937,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 244.463063146812,
#              'focalYear': 2017,
#              'gap': 3.154572012644,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'UT',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.308491134168,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.310774835209,
#              'focalYear': 2017,
#              'gap': 1.04006207166901,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'UT',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 239.27071276354,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 250.479279087935,
#              'focalYear': 2017,
#              'gap': 5.828262491918,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'VA',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 244.651016596017,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 245.472006609981,
#              'focalYear': 2017,
#              'gap': 4.06292079667202,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'VA',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 241.409085813309,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.323071751215,
#              'focalYear': 2017,
#              'gap': -7.555863293367,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'VT',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 248.878935044582,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.44340164666,
#              'focalYear': 2017,
#              'gap': -6.15602406171601,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'VT',
#              'scale': 'MRPCM',
#              'sig': 'LOWER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 246.599425708376,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 243.258777179759,
#              'focalYear': 2017,
#              'gap': 0.872476157093985,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.386301022665,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 240.087295337186,
#              'focalYear': 2017,
#              'gap': -2.03432542277301,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WA',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.121620759959,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 241.684616704069,
#              'focalYear': 2017,
#              'gap': -2.98840641651103,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WI',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 244.67302312058,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 238.982809375714,
#              'focalYear': 2017,
#              'gap': -3.42726000114601,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WI',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.41006937686,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 236.527612044354,
#              'focalYear': 2017,
#              'gap': 2.53350471651697,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WV',
#              'scale': 'MRPCM',
#              'sig': 'EQUAL',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 233.994107327837,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 235.582177604129,
#              'focalYear': 2017,
#              'gap': 3.652638527504,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WV',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 231.929539076625,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 249.431755771618,
#              'focalYear': 2017,
#              'gap': 6.48471868858798,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WY',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 242.94703708303,
#              'targetYear': 2009,
#              'valLabel': 'Male',
#              'valValue': '1',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'},
#             {'focalErrorFlag': 0,
#              'focalSample': 'R3',
#              'focalValue': 246.067565483992,
#              'focalYear': 2017,
#              'gap': 5.07798330919601,
#              'grade': 4,
#              'isFocalStatDisplayable': 1,
#              'isSigDisplayable': 1,
#              'isTargetStatDisplayable': 1,
#              'jurisdiction': 'WY',
#              'scale': 'MRPCM',
#              'sig': 'HIGHER',
#              'statType': 'MN:MN',
#              'subject': 'MAT',
#              'targetErrorFlag': 0,
#              'targetSample': 'R3',
#              'targetValue': 240.989582174796,
#              'targetYear': 2009,
#              'valLabel': 'Female',
#              'valValue': '2',
#              'variable': 'GENDER',
#              'variableLabel': 'Gender'}],
#  'status': 200}
